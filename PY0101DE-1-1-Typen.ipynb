# %% [markdown]
# <a href="https://cognitiveclass.ai/">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Ad/CCLog.png" width="100" align="center"> <img src="https://i1.wp.com/www.nmssemriach.at/wp-content/uploads/2019/11/cropped-Logo_Semriach_RGB-2.png" width="300" align="center"></a>
# <h4><i>Bearbeitung:</i> <b>March Harald - NMS Semriach</b></h4>

# %% [markdown]
# <h1>Python - Schreibe die ersten Zeilen Code in Python!</h1>

# %% [markdown]
# <p><strong>Willkommen!</strong> Dieses Notebook wird Dir die Grundlagen der Programmiersprache Python vermitteln. Obwohl die hier vorgestellten Informationen recht einfach sind, ist es eine wichtige Grundlage, die dir helfen wird, Python-Code zu lesen und zu schreiben. Am Ende dieses Notebooks wirst du die Grundlagen von Python kennen, einschließlich wie man grundlegende Befehle schreibt, einige grundlegende Typen versteht und wie man einfache Operationen mit ihnen ausführt.

# %% [markdown]
# <h2 id="Hello">Sage der Welt "Hallo" mit Python </h2>

# %% [markdown]
# Beim Erlernen einer neuen Programmiersprache ist es üblich, mit einem "Hello World"-Beispiel zu beginnen. So einfach wie es ist, diese eine Zeile Code wird sicherstellen, dass wir wissen, wie man eine Zeichenkette in der Ausgabe druckt und wie man Code in Zellen in einem Notebook ausführt.

# %% [markdown]
# <hr/>
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
# [Tipp]: Um den Python-Code in der untenstehenden Codezelle auszuführen, einfach auf die Zelle klicken, um sie auszuwählen und <kbd>Shift</kbd> + <kbd>Enter</kbd> drücken.
# </div>
# <hr/>

# %%
# Probiere deine erste Ausgabe in Python aus

print('Hallo, Python!')

# %% [markdown]
# Nachdem du die Zelle oben ausgeführt hast, solltest du sehen, dass Python <code>Hallo, Python!</code> ausgibt. Herzlichen Glückwunsch zum Ausführen deines ersten Python-Codes!

# %% [markdown]
# <hr/>
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
#     [Tip:] <code>print()</code> ist eine Funktion. Du hast die Zeichenkette <code>'Hallo, Python!'</code> als Argument übergeben, um Python anzuweisen, was es ausgeben soll.
# </div>
# <hr/>

# %% [markdown]
# <h3 id="version">Welche Version von Python verwenden wir?</h3>

# %% [markdown]
# <p>
#     Es gibt zwei beliebte Versionen der Programmiersprache Python, die heute im Einsatz sind: Python 2 und Python 3. Die Python-Community hat beschlossen, von Python 2 zu Python 3 überzugehen, und viele beliebte Bibliotheken haben angekündigt, dass sie Python 2 nicht mehr unterstützen werden.
# </p>
# <p>
#     Da Python 3 die Zukunft ist, werden wir es in diesem Kurs exklusiv einsetzen. Woher wissen wir, dass unser Notebook von einer Python 3 Runtime ausgeführt wird? Wir können in der rechten oberen Ecke dieses Notebooks nachsehen und sehen dort "Python 3" stehen, wenn wir mit der Maus über die RAM-Anzeige fahren.
# </p>
# <p>
#     Wir können aber auch gleich direkt Python selbst befragen und bekommen dann eine detaillierte Antwort. Versuche, den folgenden Code auszuführen:
# </p>

# %%
# Checke die Version von Python

import sys
print(sys.version)

# %% [markdown]
# <hr/>
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
#     [Tipp:] <code>sys</code> ist ein integriertes Modul, das viele systemspezifische Parameter und Funktionen enthält, einschließlich der verwendeten Python-Version. Bevor wir es verwenden, müssen wir es ausdrücklich <code>import</code>ieren.
# </div>
# <hr/>

# %% [markdown]
# <h3 id="comments">Kommentare schreiben in Python</h3>

# %% [markdown]
# <p>
#     Es ist immer eine gute Idee, nicht nur Code zu schreiben, sondern deinem Code auch Kommentare hinzuzufügen. Es wird anderen helfen zu verstehen, was du versucht hast zu erreichen (der Grund, warum du einen bestimmten Ausschnitt des Codes geschrieben hast). Dies hilft nicht nur <strong>anderen Leuten</strong>, deinen Code zu verstehen, es kann auch als Erinnerung dienen <strong>für dich</strong>, wenn du Wochen oder Monate später darauf zurückkommst.</p>
#
# <p>
#     Um Kommentare in Python zu schreiben, benutze das Zahlensymbol <code>#</code>, bevor du deinen Kommentar schreibst. Wenn du deinen Code ausführst, ignoriert Python alles, was hinter dem <code>#</code> in einer bestimmten Zeile steht.
# </p>

# %%
# Übung im Schreiben von Kommentaren

print('Hallo, Python!') # Diese Zeile gibt eine Zeichenkette aus.
print('Hi')

# %% [markdown]
# <p>
#     Nach der Ausführung der obigen Zelle solltest du beachten, dass <code>Diese Zeile gibt eine Zeichenkette aus</code> nicht in der Ausgabe erschienen ist, da es sich um einen Kommentar handelte (und somit von Python ignoriert wurde).
# </p>
# <p>
#     Die zweite Zeile wurde auch nicht ausgeführt, weil <code>print('Hi')</code> ebenfalls mit dem Nummernzeichen (<code>#</code>) versehen war! Da es sich hierbei nicht um einen erklärenden Kommentar des Programmierers, sondern um eine tatsächliche Codezeile handelt, sagt man, dass der Programmierer diese zweite Zeile des Codes <em>auskommentiert hat</em>.
# </p>

# %% [markdown]
# <h3 id="errors">Fehler (Errors) in Python</h3>

# %% [markdown]
# <p>Jeder macht Fehler. Für viele Arten von Fehlern wird Python dir sagen, dass du einen Fehler gemacht hast, indem es dir eine Fehlermeldung ausgibt. Es ist wichtig, die Fehlermeldungen sorgfältig zu lesen, um wirklich zu verstehen, wo du einen Fehler gemacht hast und wie du ihn korrigieren kannst.</p>
# <p>Zum Beispiel, wenn du <code>print</code> als <code>frint</code> schreibst, wird Python eine Fehlermeldung anzeigen. Probieren es aus:</p>

# %%
# Print falsch geschrieben erzeugt eine Fehlermeldung

print("Hallo, Python!")

# %% [markdown]
# <p>Die Fehlermeldung sagt dir in diesem Fall:
# <ol>
#     <li>wo (hier: in Zeile 2) der Fehler aufgetreten ist (nützlicher bei großen Notebookzellen oder Skripten), und</li>
#     <li>welcher Art von Fehler es war (hier: NameError)</li>
# </ol>
# <p>Hier hat Python hat versucht, die Funktion <code>frint</code> auszuführen, konnte aber nicht feststellen, was <code>frint</code> ist, da es sich um keine eingebaute Funktion handelt und sie auch nicht vorher von uns definiert wurde.</p>

# %% [markdown]
# <p>
#     Du wirst feststellen, dass, wenn wir einen anderen Fehler machen, indem wir vergessen, die Zeichenkette zu schließen, wir einen anderen Fehler erhalten (z.B. einen <code>SyntaxError</code>). Probiere es unten aus:
# </p>

# %%
# Teste die eingebaute Fehlermeldung.

print("Hallo, Python!")

# %% [markdown]
# <h3 id="python_error">Erkennt Python deinen Fehler, bevor es deinen Code ausführt?</h3>

# %% [markdown]
# Python ist eine so genannte <em>interpretierte Sprache</em> im Gegensatz zu <em>kompilierten</em> (übersetzten) Sprachen. Kompilierte Sprachen untersuchen dein gesamtes Programm zur Kompilierzeit und sind in der Lage, dich vor der Ausführung über eine ganze Reihe von Fehlern zu informieren. Im Gegensatz dazu interpretiert Python dein Skript Zeile für Zeile, während es ausgeführt wird. Python hört auf, das gesamte Programm auszuführen, wenn es auf einen Fehler stößt (es sei denn, der Fehler wird vom Programmierer erwartet und behandelt, einem fortgeschritteneren Thema, das wir später in diesem Kurs behandeln werden).

# %% [markdown]
# Probier den Code in der Zelle unten aus und sieh, was passiert:

# %%
# Zeichenkette und Fehler ausgeben, um die Reihenfolge der Ausführung zu sehen.

print("Das wird ausgegeben.")
frint("Das führt zu einem Fehler.")
print("Das wird NICHT ausgegeben.")

# %% [markdown]
# <h3 id="exercise">Übung: Dein erstes Programm</h3>

# %% [markdown]
# <p>Generationen von Programmierern haben ihre Programmierkarriere mit der einfachen Ausgabe von "Hello, world!" begonnen. Du wirst in ihre Fußstapfen treten.</p>
# <p>Verwende in der Codezelle unten die Funktion <code>print()</code>, um eben diesen Ausruf anzuzeigen: <code>Hello, World!</code></p>

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.
print('Hello, world')

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
#
# print("Hello, world!")
#
# -->

# %% [markdown]
# <p>Erweitern wir nun deinen Code mit einem Kommentar. Drucke in der untenstehenden Codezelle die Phrase aus: <code>Hello, world!</code> und kommentiere sie mit dem Satz <code>Ausgabe des traditionellen Hello World</code> - alles in einer Codezeile.</p>

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.
print('Hello, world')        # Ausgabe des traditionellen Hello World

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
#
# print("Hello, world!") # Ausgabe des traditionellen Hello World
#
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# <h2 id="types_objects" align="center">Objekttypen in Python</h2>

# %% [markdown]
# <p>Python ist eine objektorientierte Sprache. Es gibt viele verschiedene Arten von Objekten in Python. Beginnen wir mit den gängigsten Objekttypen: <i>String</i>, <i>Integer</i> und <i>Float</i>. Immer wenn du in Python Wörter (Text) schreiben willst, verwendest du <i>Zeichenketten</i> (kurz Strings). Die gebräuchlichsten Zahlen sind dagegen <i>Integer</i> (z.B. -1, 0, 100) und <i>Floats</i>, die reelle Zahlen darstellen (z.B. 3.14, -42.0).</p>

# %% [markdown]
# <a align="center">
#     <img src="http://march.nmssemriach.at/pythonkurs/bilder/stringsintegersfloats.png" width="600">
# </a>

# %% [markdown]
# <p>Die folgenden Codezellen enthalten einige Beispiele.</p>

# %%
# Integer

11+12

# %%
# Float (beachte den Punkt als Kommazeichen!!)

2.14+1

# %%
# String

"Hello, Python 101!"

# %% [markdown]
# <p>Du kannst Python dazu bringen, dir den Typ eines Ausdrucks mitzuteilen, indem du die eingebaute Funktion <code>type()</code> verwendest. Du wirst feststellen, dass Python sich auf ganze Zahlen als <code>int</code>, Fließkommazahlen als <code>float</code> und Zeichenketten als <code>str</code> bezieht.</p>

# %%
# Typ von 12

type(12)

# %%
# Typ von 2.14

type(2.14)

# %%
# Typ von "Hello, Python 101!"

type("Hello, Python 101!")

# %% [markdown]
# <p>Benutze in der Codezelle unten die Funktion <code>type()</code>, um den Objekttyp von <code>12.0</code> zu überprüfen.

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.
type(12.0)

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
#
# type(12.0)
#
# -->

# %% [markdown]
# <h3 id="int">Integer</h3>

# %% [markdown]
# <p>Hier sind einige Beispiele für Ganzzahlen bzw. Integer. Integer können negative oder positive Zahlen sein:</p>

# %% [markdown]
# <a align="center">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%201/Images/TypesInt.png" width="600">
# </a>

# %% [markdown]
# <p>Wir können das mit Hilfe der Funktion <code>type()</code> überprüfen, wie du sicher schon vermutet hast:

# %%
# Gib den Typ von -1 aus

type(1)

# %%
# Gib den Typ von 4 aus
type(4/3)
4/3

# %%
# Gib den Typ von 0 aus
type(0)

# %% [markdown]
# <h3 id="float">Floats</h3>

# %% [markdown]
# <p>Floats repräsentieren reelle Zahlen; sie sind eine Obermenge von ganzen Zahlen, beinhalten aber auch "Zahlen mit Dezimalstellen". Es gibt einige Einschränkungen, wenn es darum geht, dass Maschinen reelle Zahlen darstellen, aber Gleitkommazahlen sind in den meisten Fällen eine gute Darstellung. Du kannst mehr über die Besonderheiten von Floats in deiner Laufzeitumgebung erfahren, indem du den Wert von <code>sys.float_info</code> überprüfst. Dies wird dir auch sagen, was die größte und kleinste Zahl ist, die mit ihnen dargestellt werden kann.</p>
#
# <p>Noch einmal, man kann einige Beispiele mit der Funktion <code>type()</code> testen:</p>

# %%
# Gib den Typ von 1.0 aus

type(1.0) # Beachte, dass 1 ein int ist und 1.0 ein float ist.

# %%
# Gib den Typ von 0.5 aus

type(0.5)

# %%
# Gib den Typ von 0.56 aus

type(0.56)

# %%
# Systemeinstellungen zum Float-Typ

sys.float_info

# %% [markdown]
# <h3 id="convert">Konvertierung von einem Objekttyp in einen anderen</h3>

# %% [markdown]
# <p>Du kannst den Typ des Objekts in Python ändern; dies wird als Typecasting bezeichnet. Du kannst beispielsweise einen <i>Integer</i>-Wert in einen <i>Float</i>-Wert (z.B. 2 in 2.0) umwandeln (konvertieren).</p>
# <p>Probieren wir es aus:</p>

# %%
# Überprüfung, ob es sich um eine Ganzzahl (Integer) handelt.

type(2)

# %% [markdown]
# <h4>Umwandlung (Casting) von ganzen Zahlen in Gleitkommazahlen</h4>
# <p>Wir möchten den Integerwert 2 in einen Floatwert umwandeln:</p>

# %%
# Konvertiere 2 zu float

float(2)

# %%
# Konvertiere 2 (integer) zu float und überprüfe diesen Wert

type(float(2))

# %% [markdown]
# <p>Wenn wir eine ganze Zahl in einen Float umwandeln, ändern wir nicht wirklich den Wert (d.h. die Genauigkeit) der Zahl. Wenn wir jedoch einen Float in eine Ganzzahl umwandeln, könnten wir möglicherweise einige Informationen verlieren. Wenn wir zum Beispiel den Float 1.1 nach Integer umwandeln, erhalten wir 1 und verlieren die Dezimalinformationen (d.h. 0.1):</p>

# %%
# Das Casting von 1.1 in eine ganze Zahl führt zum Verlust von Informationen.

int(1.1)

# %% [markdown]
# <h4>Konvertierung von Strings in Integer oder Floats</h4>

# %% [markdown]
# <p>Manchmal haben wir einen String, der eine Zahl enthält. Wenn dies der Fall ist, können wir den String, der eine Zahl repräsentiert, mit <code>int()</code> in eine Integer-Zahl umwandeln:</p>

# %%
# Konvertiere einen String in einen Integer-Wert.

int('1')

# %% [markdown]
# <p>Aber wenn du versuchst, dies mit einem String zu machen, der nicht perfekt mit einer Zahl übereinstimmt, wirst du einen Fehler erhalten. Versuche es einmal:</p>

# %%
# Konvertiere einen String in einen Integer-Wert mit Fehler

int('1 or 2 people')

# %% [markdown]
# <p>Du kannst auch Strings mit Fließkommazahlen in <i>float</i> Objekte konvertieren:</p>

# %%
# Konvertiere den String "1.2" in einen Float

float('1.2')

# %% [markdown]
# <hr/>
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
#     [Tipp:] Dabei ist zu beachten, dass Strings mit einfachen Anführungszeichen (<code>'1.2'</code>) oder doppelten Anführungszeichen (<code>"1.2"</code>) dargestellt werden können, aber man kann nicht beides miteinander vermischen (z.B. <code>"1.2'</code>).
# </div>
# <hr/>

# %% [markdown]
# <h4>Konvertieren von Zahlen in Strings</h4>

# %% [markdown]
# <p>Wenn wir Strings in Zahlen konvertieren können, ist es nur selbstverständlich anzunehmen, dass wir Zahlen auch in Strings umwandeln können, oder?</p>

# %%
# Konvertiert eine Integer-Zahl in einen String.

str(1)
'1'+'3'

# %% [markdown]
# <p>Und es gibt keinen Grund, warum wir nicht auch Floats in Strings umwandeln sollten:</p>

# %%
# Konvertiert einen Float in einen String.

str(1.2)

# %% [markdown]
# <h3 id="bool">Boole'scher Datentyp</h3>

# %% [markdown]
# <p><i>Boolean</i> ist ein weiterer wichtiger Typ in Python. Ein Objekt vom Typ <i>Boolean</i> kann einen von zwei Werten annehmen: <code>True</code> oder <code>False</code>:</p>

# %%
# Wert true

True

# %% [markdown]
# <p>Beachtet, dass der Wert <code>True</code> einen Großbuchstaben "T" hat. Dasselbe gilt für <code>False</code> (d.h. du musst den Großbuchstaben "F" verwenden).</p>

# %%
# Wert false

False

# %% [markdown]
# <p>Wenn du Python aufforderst, den Typ eines booleschen Objekts anzuzeigen, zeigt es <code>bool</code> an, was für <i>boolean</i> steht:</p>

# %%
# Typ von True

type(True)

# %%
# Typ von False

type(False)

# %% [markdown]
# <p>Wir können boolesche Objekte in andere Datentypen umwandeln. Wenn wir einen Boolean mit einem Wert von <code>True</code> in einen Integer oder Float umwandeln, erhalten wir eine Eins. Wenn wir einen Boolean mit einem Wert von <code>False</code> nach integer oder float umwandeln, erhalten wir eine Null. Ähnlich, wenn wir eine 1 nach Boolean umwandeln, erhalten wir auch <code>True</code>. Und wenn wir eine 0 nach Boolean umwandeln, erhalten wir <code>False</code>. Versuchen wir es mal:</p>

# %%
# Konvertieren von True zu int

int(True)

# %%
# Konvertiert 1 in boolean

bool(1)

# %%
# Konvertiert 0 in boolean

bool(0)

# %%
# True in float konvertieren

float(True)

# %% [markdown]
# <h3 id="exer_type">Übung: Typen</h3>

# %% [markdown]
# <p>Was ist der Datentyp des Ergebnisses von: <code>6 / 2</code>?</p>

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.
type(6/2)

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# type(6/2) # float
# -->

# %% [markdown]
# <p>What is the type of the result of: <code>6 // 2</code>? (Note the double slash <code>//</code>.)</p>

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.
5/2

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# type(6//2) # int, as the double slashes stand for integer division
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# <h2 id="expressions">Ausdrücke und Variablen</h2>

# %% [markdown]
# <h3 id="exp">Ausdrücke</h3>

# %% [markdown]
# <p>Ausdrücke in Python können Operationen zwischen kompatiblen Typen (z.B. Integer und Floats) beinhalten. Zum Beispiel grundlegende arithmetische Operationen wie das Addieren mehrerer Zahlen mit dem Additions-Operator +:</p>

# %%
# Addition

43 + 60 + 16 + 41

# %% [markdown]
# <p>Wir können Subtraktionsoperationen mit dem Minus-Operator - durchführen. In diesem Fall ist das Ergebnis eine negative Zahl:</p>

# %%
# Subtraktion

50 - 60

# %% [markdown]
# <p>Wir können die Multiplikation mit einem Sternchen durchführen:</p>

# %%
# Multiplikation

5 * 5

# %% [markdown]
# <p>Wir können auch eine Division mit dem Schrägstrich durchführen:

# %%
# Division

25 / 5

# %%
# Division

25 / 6

# %% [markdown]
# <p>Wie im Vergleich mit den obigen Beispielen zu sehen ist, können wir den doppelten Schrägstrich für die Ganzzahldivision verwenden, wobei das Ergebnis auf die nächste Ganzzahl gerundet wird:

# %%
# Ganzzahldivision

25 // 5

# %%
# Ganzzahldivision

25 // 6

# %% [markdown]
# <h3 id="exer_exp">Übung: Ausdrücke</h3>

# %% [markdown]
# <p>Schreiben wir einen Ausdruck, der berechnet, wie viele Stunden 160 Minuten entsprechen:

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.
160/60

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# 160/60
# # Or
# 160//60
# -->

# %% [markdown]
# <p>Python folgt bei der Auswertung mathematischer Ausdrücke den üblichen mathematischen Regeln. Im folgenden Beispiel addiert Python 30 zum Ergebnis der Multiplikation (d.h. 120).

# %%
# Mathematischer Ausdruck

30 + 2 * 60

# %% [markdown]
# <p>Und genau wie in der Mathematik haben auch in Klammern eingeschlossene Ausdrücke den Vorrang. Im Folgenden wird also 32 mit 60 multipliziert.

# %%
# Mathematischer Ausdruck

(30 + 2) * 60

# %% [markdown]
# <h3 id="var">Variablen</h3>

# %% [markdown]
# <p>Wie bei den meisten Programmiersprachen können wir Werte in <i>Variablen</i> speichern, damit wir sie später verwenden können. Zum Beispiel:</p>

# %%
# Wert in Variable speichern

x = 43 + 60 + 16 + 41

# %% [markdown]
# <p>Um den Wert von <code>x</code> in unserem Notebook zu sehen, können wir ihn einfach auf die letzte Zeile einer Zelle setzen:</p>

# %%
# Ausgabe des Wertes in der Variable

x

# %% [markdown]
# <p>Wir können auch Operationen mit <code>x</code> durchführen und das Ergebnis in einer neuen Variablen speichern:</p>

# %%
# Verwendung einer anderen Variablen, um das Ergebnis der Operation zu speichern

y = x / 60
y

# %% [markdown]
# <p>Wenn wir einen Wert in einer bestehenden Variablen speichern, überschreibt der neue Wert den vorherigen Wert:</p>

# %%
# Überschreiben der Variablen mit einem neuen Wert

x = x / 60
x

# %% [markdown]
# <p>Es ist empfehlenswert, sinnvolle Variablennamen zu verwenden, damit du und andere den Code lesen und leichter verstehen können:</p>

# %%
# Bezeichne die Variablen sinnvoll

gesamt_min = 43 + 42 + 57 # Gesamtlänge der Musikalben in Minuten
gesamt_min

# %%
# Bezeichne die Variablen sinnvoll

gesamt_stunden = gesamt_min / 60 # Gesamtlänge der Musikalben in Stunden
gesamt_stunden

# %% [markdown]
# <p>In den obigen Zellen haben wir die Länge von drei Alben in Minuten hinzugefügt und in <code>gesamt_min</code> gespeichert. Wir haben den Wert dann durch 60 geteilt, um die Gesamtlänge <code>gesamt_stunden</code> in Stunden zu berechnen. Du kannst das auch alles auf einmal in einem einzigen Ausdruck erledigen, solange du die Länge des Albums in Klammern setzt, bevor du teilst, wie unten gezeigt.</p>

# %%
# Komplizierterer Ausdruck

gesamt_stunden = (43 + 42 + 57) / 60  # Gesamtstunden in einem einzigen Ausdruck
gesamt_stunden

# %% [markdown]
# <p>Wenn du lieber die Gesamtstunden als Integer haben möchtest, kannst du natürlich die Gleitkomma-Division durch eine Integer-Division ersetzen (z.B., <code>//</code>).</p>

# %% [markdown]
# <h3 id="exer_exp_var">Übung: Ausdrücke und Variablen in Python</h3>

# %% [markdown]
# <p>Was ist der Wert von <code>x</code> wenn <code>x = 3 + 2 * 2</code></p>

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.
x=3+2*2
x

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# 7
# -->

# %% [markdown]
# <p>Was ist der Wert von <code>y</code> wobei <code>y = (3 + 2) * 2</code>?</p>

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.
y=(3+2)*2
y

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# 10
# -->

# %% [markdown]
# <p>Was ist der Wert von <code>z</code> wobei <code>z = x + y</code>?</p>

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.
z=x+y
z

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# 17
# -->

# %% [markdown]
# <h3>Über die Autoren:</h3>
# <p><a href="https://www.linkedin.com/in/joseph-s-50398b136/" target="_blank">Joseph Santarcangelo</a> ist Datenwissenschaftler bei IBM und promovierte in Elektrotechnik. Seine Forschung konzentrierte sich auf die Nutzung von Machine Learning, Signalverarbeitung und Computersehen, um festzustellen, wie Videos die menschliche Wahrnehmung beeinflussen. Joseph arbeitet für IBM, seit er seine Doktorarbeit abgeschlossen hat.</p>

# %% [markdown]
# <hr>
# <p>Copyright &copy; 2018 IBM Developer Skills Network. This notebook and its source code are released under the terms of the <a href="https://cognitiveclass.ai/mit-license/">MIT License</a>.</p>
