# %% [markdown]
# <h3 align=center>Erstelle ein Tupel</h3>

# %% [markdown]
# erstelle das Tupel <code> (0,1,2,3) </code> und weise es der Variablen <code> A</code> zu:

# %% [markdown]
# <h3 align=center>Die Elemente eines Tupels finden</h3>

# %% [markdown]
# Finde die ersten beiden Elemente des Tupels <code> A </code>:

# %% [markdown]
# <h3 align=center>Listen </h3>

# %% [markdown]
# Für die nächsten Fragen benötigst du die folgende Liste:

# %%
B=["a","b","c"]

# %% [markdown]
# Finde die ersten beiden Elemente der Liste <code> B</code>:

# %% [markdown]
# Ändere das erste Element der Liste in einen Großbuchstaben <code> "A" </code>

# %% [markdown]
# <hr>
# <small>Copyright &copy; 2018 IBM Cognitive Class. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/).</small>
