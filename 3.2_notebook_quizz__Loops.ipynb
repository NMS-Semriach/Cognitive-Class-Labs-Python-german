# %% [markdown]
# <h3>For Schleifen</h3>

# %% [markdown]
# Benutze Schleifen, um die Elemente der Liste <code>A</code> auszugeben

# %%
A=[1,2,3,4,5]

# %% [markdown]
# <h3>While Schleifen</h3>

# %% [markdown]
# Finde den Wert von <code> x </code>, der die Reihenfolge <code> 1,2,...,10 </code> ausgibt.

# %%
x=
y=1
while(y< x):
    print(y)
    y=y+1

# %% [markdown]
# <hr>
# <small>Copyright &copy; 2018 IBM Cognitive Class. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/).</small>
