# %% [markdown]
# <a href="https://cognitiveclass.ai/">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Ad/CCLog.png" width="100" align="center"> <img src="https://i1.wp.com/www.nmssemriach.at/wp-content/uploads/2019/11/cropped-Logo_Semriach_RGB-2.png" width="300" align="center"></a>
# <h4><i>Bearbeitung:</i> <b>March Harald - NMS Semriach</b></h4>

# %% [markdown]
# <h1>String Operationen</h1>

# %% [markdown]
# <p><strong>Willkommen!</strong> Dieses Notebook wird dir die Stringoperationen in der Programmiersprache Python erklären. Am Ende dieses Notebooks wirst du die Grundlagen der Stringoperationen in Python kennen, einschließlich Indexierung, Escape-Sequenzen und Operatoren.</p>

# %% [markdown]
# <h2 id="strings">Was sind Strings?</h2>

# %% [markdown]
# Das folgende Beispiel zeigt einen String, der innerhalb von 2 Anführungszeichen steht:

# %%
# Anführungszeichen zum Festlegen von Strings verwenden

"Michael Jackson"

# %% [markdown]
# Wir können auch einfache Anführungszeichen verwenden:

# %%
# Verwendung von einfachen Anführungszeichen bei der Definition von Strings

'Michael Jackson'

# %% [markdown]
# Ein String kann eine Kombination aus Leerzeichen und Ziffern sein:

# %%
# Ziffern und Leerzeichen in Strings

'1 2 3 4 5 6 '

# %% [markdown]
# Ein String kann auch eine Kombination von Sonderzeichen sein:

# %%
# Sonderzeichen in Strings

'@#2_#]&*^%$'

# %% [markdown]
# Wir können unseren String mit der print-Anweisung ausgeben::

# %%
# Ausgabe eines Strings

print("Hallo!")

# %% [markdown]
# Wir können einen String einer Variablen zuweisen:

# %%
# String einer Variablen zuweisen

Name = "Michael Jackson"
Name

# %% [markdown]
# <hr>

# %% [markdown]
# <h2 id="index">Indexierung</h2>

# %% [markdown]
# Es ist hilfreich, einen String als eine geordnete Zeichenfolge zu betrachten. Auf jedes Element in der Zeichenfolge kann über einen Index zugegriffen werden, der durch die Anordnung der Zahlen gekennzeichnet wird:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%201/Images/StringsIndex.png" width="600" align="center" />

# %% [markdown]
#  Auf den ersten Index kann wie folgt zugegriffen werden:

# %% [markdown]
# <hr/>
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
# [Tipp]: Da die Indizierung bei 0 beginnt, bedeutet dies, dass der erste Index auf dem Index 0 positioniert ist.
# </div>
# <hr/>

# %%
# Gibt das erste Element in dem String aus.

print(Name[0])

# %% [markdown]
#  Wir können auf Index 6 zugreifen:

# %%
# Ausgabe des Elements bei Index 6 in dem String

print(Name[6])

# %% [markdown]
# Außerdem können wir auf den 13. Index zugreifen:

# %%
# Ausgabe des Elements am 13. Index in dem String

print(Name[13])

# %% [markdown]
# <h3 id="neg">Negative Indexierung</h3>

# %% [markdown]
#  Wir können auch eine negative Indexierung mit Strings verwenden:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%201/Images/StringsNeg.png" width="600" align="center" />

# %% [markdown]
# Der negative Index kann uns helfen, das Element vom Ende des Strings aus zu numerieren.

# %% [markdown]
# Das letzte Element wird durch den Index -1 bestimmt:

# %%
# Ausgabe des letzten Elements in dem String

print(Name[-1])

# %% [markdown]
#  Das erste Element kann mit dem Index -15 erhalten werden:

# %%
# Ausgabe des ersten Elements in dem String

print(Name[-15])

# %% [markdown]
# Wir können die Anzahl der Zeichen in einer Zeichenkette finden, indem wir <code>len</code>, kurz für das englische Wort length (Länge), verwenden:

# %%
# Ermittelt die Länge des Strings

len("Michael Jackson")

# %% [markdown]
# <h3 id="slice">Textteile</h3>

# %% [markdown]
# Wir können mehrere Zeichen aus einem String mittels Abschnitten erhalten. Wir können ihn vom 0. bis 4. und vom 8. bis 12. Element abschneiden:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%201/Images/StringsSlice.png" width="600" align="center" />

# %% [markdown]
# <hr/>
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
# [Tipp]: Bei der Verwendung von Abschnitten bedeutet die erste Zahl den Index (Start bei 0) und die zweite Zahl die Länge vom Index bis zum letzten gewünschten Element (Start bei 1, dh von zB. Index0 bis Index0 ist die Länge = 1).
# </div>
# <hr/>

# %%
# Verwende nur den Abschnitt von Index 0 bis Index 3 des Strings in der Variablen Name.

Name[0:4]

# %%
# Verwende nur den Abschnitt von Index 8 bis Index 11 des Strings in der Variablen Name.

Name[8:12]

# %% [markdown]
# <h3 id="stride">Schrittweite</h3>

# %% [markdown]
# Wir können auch wie folgt einen Schrittweitenwert eingeben, wobei die Zahl '2' anzeigt, dass wir jeden zweiten Buchstaben auswählen:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%201/Images/StringsStride.png" width="600" align="center" />

# %%
# Ausgabe jedes zweiten Elements. Die Elemente mit den Indizes 1, 3, 5.....

Name[::2]

# %% [markdown]
# Wir können auch Abschnitte mit Schrittweiten kombinieren. In diesem Fall wählen wir die ersten fünf Elemente aus und verwenden dann die Schrittweite:

# %%
# Liefert jedes zweite Element im Bereich von Index 0 bis Index 4.

Name[0:5:2]

# %% [markdown]
# <h3 id="concat">Aneinanderfügen von Strings</h3>

# %% [markdown]
# Wir können Strings verketten oder kombinieren, indem wir die Additionssymbole verwenden, und das Ergebnis ist ein neuer String, der eine Kombination aus allen ist:

# %%
# Verkettung von zwei Strings

Bewunderung = Name + "ist der Beste"
Bewunderung

# %% [markdown]
# Um Werte eines Strings zu vervielfältigen, multiplizieren wir den String einfach mit der Anzahl der Male, die wir ihn vervielfältigen möchten. In diesem Fall ist die Zahl drei. Das Ergebnis ist ein neuer String, und dieser neue String besteht aus drei Kopien des ursprünglichen Strings:

# %%
# Den String 3 mal schreiben.

3 * "Michael Jackson"

# %% [markdown]
# Du kannst einen neuen String erstellen, indem du ihn auf die ursprüngliche Variable setzt. Verknüpft mit einer neuen Zeichenkette entsteht ein neuer String, der von Michael Jackson zu "Michael Jackson ist der Beste" wechselt.

# %%
# Strings verketten

Name = "Michael Jackson"
Name = Name + " ist der Beste"
Name

# %% [markdown]
# <hr>

# %% [markdown]
# <h2 id="escape">Escape-Sequenzen</h2>

# %% [markdown]
# Backslashes (\) bilden den Anfang von Escape-Sequenzen. Escape-Sequenzen stellen Zeichenketten dar, die schwer einzugeben sind. Beispielsweise repräsentiert "\n" eine neue Zeile. Die Ausgabe erfolgt durch eine neue Zeile dort wo "\n" steht:

# %%
# Escape-Sequenz für Zeilenumbrüche

print(" Michael Jackson \n ist der Beste" )

# %% [markdown]
# Ebenso stellt "\t" einen Tabulator dar:

# %%
# Escape-Sequenz für Tabulatoren

print(" Michael Jackson \t ist der Beste" )

# %% [markdown]
# Wenn du einen Backslash in deinen String einfügen möchtest, verwende einen doppelten Backslash:

# %%
# Einfügen eines Backslashs in einen String

print(" Michael Jackson \\ ist der Beste" )

# %% [markdown]
# Wir können auch ein "r" vor die Zeichenkette setzen, um den Backslash anzuzeigen:

# %%
# r teilt Python mit, dass diese Zeichenkette als 'roher' String (englisch 'raw') angezeigt wird.

print(r" Michael Jackson \ ist der Beste" )

# %% [markdown]
# <hr>

# %% [markdown]
# <h2 id="operations">String Operationen</h2>

# %% [markdown]
# Es gibt viele Methoden zum Bearbeiten von Zeichenketten in Python, die verwendet werden können, um Texte zu manipulieren. Wir werden einige grundlegende Zeichenkettenoperationen auf Texte anwenden.

# %% [markdown]
# Beginnen wir mit der Methode <code>upper</code>; diese Methode konvertiert Kleinbuchstaben in Großbuchstaben:

# %%
# Konvertiert alle Zeichen in Strings in Großbuchstaben.

A = "Thriller ist sein sechstes Studioalbum"
print("vor upper:", A)
B = A.upper()
print("nach upper:", B)

# %% [markdown]
# Die Methode <code>replace</code> ersetzt ein Segment des Strings, d.h. einen Teilstring durch einen neuen String. Wir geben den Teil des Strings ein, den wir ändern möchten. Das zweite Argument ist, womit wir das Segment austauschen möchten, und das Ergebnis ist ein neuer String mit geändertem Segment:

# %%
# Ersetzt den alten Teilstring durch den neuen Teilstring, wenn das Segment in dem String gefunden wurde.

A = "Michael Jackson ist der Beste"
B = A.replace('Michael', 'Janet')
B

# %% [markdown]
# Die Methode <code>find</code> findet einen Teilstring (Substring). Das Argument ist der Teilstring, den du finden möchtest, und das Ergebnis ist der erste Index mit dieser Sequenz. Wir können den Substring <code>jack</code> oder <code>el<code> finden.

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%201/Images/StringsFind.png" width="600" align="center" />

# %%
# Finde den Teilstring in dem String. Nur der Index des ersten Teilstrings in der Zeichenkette ist das Ergebnis.

Name = "Michael Jackson"
Name.find('el')

# %%
# Finde den Substring im String.

Name.find('Jack')

# %% [markdown]
# Wenn sich der Substring nicht in der Zeichenkette befindet, dann ist das Ergebnis negativ. Beispielsweise ist die Zeichenkette 'Jasdfasdasdf' kein Substring:

# %%
# Wenn der Substring im String nicht gefunden wird.

Name.find('Jasdfasdasdf')

# %% [markdown]
# <hr>

# %% [markdown]
# <h2 id="quiz">Quiz zu Strings</h2>

# %% [markdown]
# Was ist der Wert der Variablen <code>A</code>, nachdem der folgende Code ausgeführt wurde?

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.

A = "1"

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# "1"
# -->

# %% [markdown]
# Was ist der Wert der Variablen <code>B</code>, nachdem der folgende Code ausgeführt wurde?

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.

B = "2"

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# "2"
# -->

# %% [markdown]
# Was ist der Wert der Variablen <code>C</code>, nachdem der folgende Code ausgeführt wurde?

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.

C = A + B

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# "12"
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# Von der Variablen <code>D</code> sollen nur die ersten drei Elemente ausgegeben werden:

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.

D = "ABCDEFG"

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# print(D[:3])
# # or
# print(D[0:3])
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# Benutze einen Schrittwert von 2, um jedes zweite Zeichen der Zeichenkette <code>E</code> auszugeben:

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.

E = 'clocrkr1e1c1t'

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# print(E[::2])
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# Gib einen Backslash mit <code>print</code> aus:

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# print("\\")
# or
# print(r" \ ")
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# Die Variable <code>F</code> muss in Großbuchstaben umgewandelt werden:

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.

F = "You are wrong"

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# F.upper()
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# Nimm die Variable <code>G</code>, und suche den ersten Index des Substrings <code>snow</code>:

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.

G = "Mary had a little lamb Little lamb, little lamb Mary had a little lamb \
Its fleece was white as snow And everywhere that Mary went Mary went, Mary went \
Everywhere that Mary went The lamb was sure to go"

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# G.find("snow")
# -->

# %% [markdown]
# Ersetze in der Variablen <code>G</code> den Substring <code>Mary</code> durch <code>Bob</code>:

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
# G.replace("Mary", "Bob")
# -->

# %% [markdown]
# <hr>
# <p>Copyright &copy; 2018 IBM Developer Skills Network. This notebook and its source code are released under the terms of the <a href="https://cognitiveclass.ai/mit-license/">MIT License</a>.</p>
