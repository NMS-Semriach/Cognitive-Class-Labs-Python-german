# %% [markdown]
# Du benötigst das Dictionary <code>D</code> für die Übungen:

# %%
D={'a':0,'b':1,'c':2}

# %% [markdown]
# <h3>Ein Dictionary abfragen</h3>

# %% [markdown]
# Finde den Wert für den Schlüssel <code> 'a' </code>

# %% [markdown]
# <h3>Schlüssel (Keys)</h3>

# %% [markdown]
# Finde die Schlüssel des Dictionaries <code>D</code>

# %% [markdown]
# <hr>
# <small>Copyright &copy; 2018 IBM Cognitive Class. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/).</small>
