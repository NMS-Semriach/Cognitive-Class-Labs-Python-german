# %% [markdown]
# <a href="https://cognitiveclass.ai/">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Ad/CCLog.png" width="200" align="center">
# </a>
# <h3><i>Bearbeitung:</i> <b>March Harald - NMS Semriach</b></h3>

# %% [markdown]
# <h1>Python - Schreibe die ersten Zeilen Code in Python!</h1>

# %% [markdown]
# <p><strong>Willkommen!</strong> Dieses Notebook wird Dir die Grundlagen der Programmiersprache Python vermitteln. Obwohl die hier vorgestellten Informationen recht einfach sind, ist es eine wichtige Grundlage, die dir helfen wird, Python-Code zu lesen und zu schreiben. Am Ende dieses Notebooks wirst du die Grundlagen von Python kennen, einschließlich wie man grundlegende Befehle schreibt, einige grundlegende Typen versteht und wie man einfache Operationen mit ihnen ausführt.

# %% [markdown]
# <h2>Inhaltsverzeichnis</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="#hello">Sage der Welt "Hallo" mit Python</a>
#             <ul>
#                 <li><a href="version">Welche Version von Python verwenden wir?</a></li>
#                 <li><a href="comments">Kommentare schreiben in Python</a></li>
#                 <li><a href="errors">Fehler (Errors) in Python</a></li>
#                 <li><a href="python_error">Erkennt Python Fehler bevor der Code ausgeführt wird?</a></li>
#                 <li><a href="exercise">Übung: Dein erstes Programm</a></li>
#             </ul>
#         </li>
#         <li>
#             <a href="#types_objects">Objekt-Typen in Python</a>
#             <ul>
#                 <li><a href="int">Integers</a></li>
#                 <li><a href="float">Floats</a></li>
#                 <li><a href="convert">Umwandlung (Konvertierung) von einem Objekttyp in einen anderen</a></li>
#                 <li><a href="bool">Boolescher Datentyp (Boolean)</a></li>
#                 <li><a href="exer_type">Übung: Typen</a></li>
#             </ul>
#         </li>
#         <li>
#             <a href="#expressions">Ausdrücke und Variablen</a>
#             <ul>
#                 <li><a href="exp">Ausdrücke</a></li>
#                 <li><a href="exer_exp">Übung: Ausdrücke</a></li>
#                 <li><a href="var">Variablen</a></li>
#                 <li><a href="exer_exp_var">Übung: Ausdrücke und Variablen in Python</a></li>
#             </ul>
#         </li>
#     </ul>
#     <p>
#         ungefähr benötigte Zeit: <strong>25 min</strong>
#     </p>
# </div>
#
# <hr>

# %% [markdown]
# <h2 id="Hello" >Sage der Welt "Hallo" mit Python </h2>

# %% [markdown]
# Beim Erlernen einer neuen Programmiersprache ist es üblich, mit einem "Hello World"-Beispiel zu beginnen. So einfach wie es ist, diese eine Zeile Code wird sicherstellen, dass wir wissen, wie man eine Zeichenkette in der Ausgabe druckt und wie man Code in Zellen in einem Notebook ausführt.

# %% [markdown]
# <hr/>
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
# [Tipp]: Um den Python-Code in der untenstehenden Codezelle auszuführen, einfach auf die Zelle klicken, um sie auszuwählen und <kbd>Shift</kbd> + <kbd>Enter</kbd> drücken.
# </div>
# <hr/>

# %%
# Probiere deine erste Ausgabe in Python aus

print('Hallo, Python!')

# %% [markdown]
# Nachdem du die Zelle oben ausgeführt hast, solltest du sehen, dass Python <code>Hallo, Python!</code> ausgibt. Herzlichen Glückwunsch zum Ausführen deines ersten Python-Codes!

# %% [markdown]
# <hr/>
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
#     [Tip:] <code>print()</code> ist eine Funktion. Du hast die Zeichenkette <code>'Hallo, Python!'</code> als Argument übergeben, um Python anzuweisen, was es ausgeben soll.
# </div>
# <hr/>

# %% [markdown]
# <h3 id="version">Welche Version von Python verwenden wir?</h3>

# %% [markdown]
# <p>
#     Es gibt zwei beliebte Versionen der Programmiersprache Python, die heute im Einsatz sind: Python 2 und Python 3. Die Python-Community hat beschlossen, von Python 2 zu Python 3 überzugehen, und viele beliebte Bibliotheken haben angekündigt, dass sie Python 2 nicht mehr unterstützen werden.
# </p>
# <p>
#     Da Python 3 die Zukunft ist, werden wir es in diesem Kurs exklusiv einsetzen. Woher wissen wir, dass unser Notebook von einer Python 3 Runtime ausgeführt wird? Wir können in der rechten oberen Ecke dieses Notebooks nachsehen und sehen dort "Python 3" stehen, wenn wir mit der Maus über die RAM-Anzeige fahren.
# </p>
# <p>
#     Wir können aber auch gleich direkt Python selbst befragen und bekommen dann eine detaillierte Antwort. Versuche, den folgenden Code auszuführen:
# </p>

# %%
# Checke die Version von Python

import sys
print(sys.version)

# %% [markdown]
# <hr/>
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
#     [Tipp:] <code>sys</code> ist ein integriertes Modul, das viele systemspezifische Parameter und Funktionen enthält, einschließlich der verwendeten Python-Version. Bevor wir es verwenden, müssen wir es ausdrücklich <code>import</code>ieren.
# </div>
# <hr/>

# %% [markdown]
# <h3 id="comments">Kommentare schreiben in Python</h3>

# %% [markdown]
# <p>
#     Es ist immer eine gute Idee, nicht nur Code zu schreiben, sondern deinem Code auch Kommentare hinzuzufügen. Es wird anderen helfen zu verstehen, was du versucht hast zu erreichen (der Grund, warum du einen bestimmten Ausschnitt des Codes geschrieben hast). Dies hilft nicht nur <strong>anderen Leuten</strong>, deinen Code zu verstehen, es kann auch als Erinnerung dienen <strong>für dich</strong>, wenn du Wochen oder Monate später darauf zurückkommst.</p>
#
# <p>
#     Um Kommentare in Python zu schreiben, benutze das Zahlensymbol <code>#</code>, bevor du deinen Kommentar schreibst. Wenn du deinen Code ausführst, ignoriert Python alles, was hinter dem <code>#</code> in einer bestimmten Zeile steht.
# </p>

# %%
# Übung im Schreiben von Kommentaren

print('Hallo, Python!') # Diese Zeile gibt eine Zeichenkette aus.
# print('Hi')

# %% [markdown]
# <p>
#     Nach der Ausführung der obigen Zelle solltest du beachten, dass <code>Diese Zeile gibt eine Zeichenkette aus</code> nicht in der Ausgabe erschienen ist, da es sich um einen Kommentar handelte (und somit von Python ignoriert wurde).
# </p>
# <p>
#     Die zweite Zeile wurde auch nicht ausgeführt, weil <code>print('Hi')</code> ebenfalls mit dem Nummernzeichen (<code>#</code>) versehen war! Da es sich hierbei nicht um einen erklärenden Kommentar des Programmierers, sondern um eine tatsächliche Codezeile handelt, sagt man, dass der Programmierer diese zweite Zeile des Codes <em>auskommentiert hat</em>.
# </p>

# %% [markdown]
# <h3 id="errors">Fehler (Errors) in Python</h3>

# %% [markdown]
# <p>Jeder macht Fehler. Für viele Arten von Fehlern wird Python dir sagen, dass du einen Fehler gemacht hast, indem es dir eine Fehlermeldung ausgibt. Es ist wichtig, die Fehlermeldungen sorgfältig zu lesen, um wirklich zu verstehen, wo du einen Fehler gemacht hast und wie du ihn korrigieren kannst.</p>
# <p>Zum Beispiel, wenn du <code>print</code> als <code>frint</code> schreibst, wird Python eine Fehlermeldung anzeigen. Probieren es aus:</p>

# %%
# Print falsch geschrieben erzeugt eine Fehlermeldung

frint("Hallo, Python!")

# %% [markdown]
# <p>Die Fehlermeldung sagt dir in diesem Fall:
# <ol>
#     <li>wo (hier: in Zeile 2) der Fehler aufgetreten ist (nützlicher bei großen Notebookzellen oder Skripten), und</li>
#     <li>welcher Art von Fehler es war (hier: NameError)</li>
# </ol>
# <p>Hier hat Python hat versucht, die Funktion <code>frint</code> auszuführen, konnte aber nicht feststellen, was <code>frint</code> ist, da es sich um keine eingebaute Funktion handelt und sie auch nicht vorher von uns definiert wurde.</p>

# %% [markdown]
# <p>
#     Du wirst feststellen, dass, wenn wir einen anderen Fehler machen, indem wir vergessen, die Zeichenkette zu schließen, wir einen anderen Fehler erhalten (z.B. einen <code>SyntaxError</code>). Probiere es unten aus:
# </p>

# %%
# Teste die eingebaute Fehlermeldung.

print("Hallo, Python!)

# %% [markdown]
# <h3 id="python_error">Erkennt Python deinen Fehler, bevor es deinen Code ausführt?</h3>

# %% [markdown]
# Python ist eine so genannte <em>interpretierte Sprache</em> im Gegensatz zu <em>kompilierten</em> (übersetzten) Sprachen. Kompilierte Sprachen untersuchen dein gesamtes Programm zur Kompilierzeit und sind in der Lage, dich vor der Ausführung über eine ganze Reihe von Fehlern zu informieren. Im Gegensatz dazu interpretiert Python dein Skript Zeile für Zeile, während es ausgeführt wird. Python hört auf, das gesamte Programm auszuführen, wenn es auf einen Fehler stößt (es sei denn, der Fehler wird vom Programmierer erwartet und behandelt, einem fortgeschritteneren Thema, das wir später in diesem Kurs behandeln werden).

# %% [markdown]
# Probier den Code in der Zelle unten aus und sieh, was passiert:

# %%
# Zeichenkette und Fehler ausgeben, um die Reihenfolge der Ausführung zu sehen.

print("Das wird ausgegeben.")
frint("Das führt zu einem Fehler.")
print("Das wird NICHT ausgegeben.")

# %% [markdown]
# <h3 id="exercise">Übung: Dein erstes Programm</h3>

# %% [markdown]
# <p>Generationen von Programmierern haben ihre Programmierkarriere mit der einfachen Ausgabe von "Hello, world!" begonnen. Du wirst in ihre Fußstapfen treten.</p>
# <p>Verwende in der Codezelle unten die Funktion <code>print()</code>, um eben diesen Ausruf anzuzeigen: <code>Hello, World!</code></p>

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.

# %% [markdown]
# Doppelklicke __hier__ um die Lösung anzuzeigen.
#
# <!-- Antwort:
#
# print("Hello, world!")
#
# -->

# %% [markdown]
# <p>Erweitern wir nun deinen Code mit einem Kommentar. Drucke in der untenstehenden Codezelle die Phrase aus: <code>Hello, world!</code> und kommentiere sie mit dem Satz <code>Ausgabe des traditionellen Hello World</code> - alles in einer Codezeile.</p>

# %%
# Gib deinen Code unten ein und drücke Shift+Enter, um ihn auszuführen.

# %% [markdown]
# Doppelklicke __hier__ um die Lösung zu sehen.
#
# <!-- Your answer is below:
#
# print("Hello, world!") # Ausgabe des traditionellen Hello World
#
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# <h2 id="types_objects" align="center">Types of objects in Python</h2>

# %% [markdown]
# <p>Python is an object-oriented language. There are many different types of objects in Python. Let's start with the most common object types: <i>strings</i>, <i>integers</i> and <i>floats</i>. Anytime you write words (text) in Python, you're using <i>character strings</i> (strings for short). The most common numbers, on the other hand, are <i>integers</i> (e.g. -1, 0, 100) and <i>floats</i>, which represent real numbers (e.g. 3.14, -42.0).</p>

# %% [markdown]
# <a align="center">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%201/Images/TypesObjects.png" width="600">
# </a>

# %% [markdown]
# <p>The following code cells contain some examples.</p>

# %%
# Integer

11

# %%
# Float

2.14

# %%
# String

"Hello, Python 101!"

# %% [markdown]
# <p>You can get Python to tell you the type of an expression by using the built-in <code>type()</code> function. You'll notice that Python refers to integers as <code>int</code>, floats as <code>float</code>, and character strings as <code>str</code>.</p>

# %%
# Type of 12

type(12)

# %%
# Type of 2.14

type(2.14)

# %%
# Type of "Hello, Python 101!"

type("Hello, Python 101!")

# %% [markdown]
# <p>In the code cell below, use the <code>type()</code> function to check the object type of <code>12.0</code>.

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell
type(12.0)

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
#
# type(12.0)
#
# -->

# %% [markdown]
# <h3 id="int">Integers</h3>

# %% [markdown]
# <p>Here are some examples of integers. Integers can be negative or positive numbers:</p>

# %% [markdown]
# <a align="center">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%201/Images/TypesInt.png" width="600">
# </a>

# %% [markdown]
# <p>We can verify this is the case by using, you guessed it, the <code>type()</code> function:

# %%
# Print the type of -1

type(-1)

# %%
# Print the type of 4

type(4)

# %%
# Print the type of 0

type(0)

# %% [markdown]
# <h3 id="float">Floats</h3>

# %% [markdown]
# <p>Floats represent real numbers; they are a superset of integer numbers but also include "numbers with decimals". There are some limitations when it comes to machines representing real numbers, but floating point numbers are a good representation in most cases. You can learn more about the specifics of floats for your runtime environment, by checking the value of <code>sys.float_info</code>. This will also tell you what's the largest and smallest number that can be represented with them.</p>
#
# <p>Once again, can test some examples with the <code>type()</code> function:

# %%
# Print the type of 1.0

type(1.0) # Notice that 1 is an int, and 1.0 is a float

# %%
# Print the type of 0.5

type(0.5)

# %%
# Print the type of 0.56

type(0.56)

# %%
# System settings about float type

sys.float_info

# %% [markdown]
# <h3 id="convert">Converting from one object type to a different object type</h3>

# %% [markdown]
# <p>You can change the type of the object in Python; this is called typecasting. For example, you can convert an <i>integer</i> into a <i>float</i> (e.g. 2 to 2.0).</p>
# <p>Let's try it:</p>

# %%
# Verify that this is an integer

type(2)

# %% [markdown]
# <h4>Converting integers to floats</h4>
# <p>Let's cast integer 2 to float:</p>

# %%
# Convert 2 to a float

float(2)

# %%
# Convert integer 2 to a float and check its type

type(float(2))

# %% [markdown]
# <p>When we convert an integer into a float, we don't really change the value (i.e., the significand) of the number. However, if we cast a float into an integer, we could potentially lose some information. For example, if we cast the float 1.1 to integer we will get 1 and lose the decimal information (i.e., 0.1):</p>

# %%
# Casting 1.1 to integer will result in loss of information

int(1.1)

# %% [markdown]
# <h4>Converting from strings to integers or floats</h4>

# %% [markdown]
# <p>Sometimes, we can have a string that contains a number within it. If this is the case, we can cast that string that represents a number into an integer using <code>int()</code>:</p>

# %%
# Convert a string into an integer

int('1')

# %% [markdown]
# <p>But if you try to do so with a string that is not a perfect match for a number, you'll get an error. Try the following:</p>

# %%
# Convert a string into an integer with error

int('1 or 2 people')

# %% [markdown]
# <p>You can also convert strings containing floating point numbers into <i>float</i> objects:</p>

# %%
# Convert the string "1.2" into a float

float('1.2')

# %% [markdown]
# <hr/>
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
#     [Tip:] Note that strings can be represented with single quotes (<code>'1.2'</code>) or double quotes (<code>"1.2"</code>), but you can't mix both (e.g., <code>"1.2'</code>).
# </div>
# <hr/>

# %% [markdown]
# <h4>Converting numbers to strings</h4>

# %% [markdown]
# <p>If we can convert strings to numbers, it is only natural to assume that we can convert numbers to strings, right?</p>

# %%
# Convert an integer to a string

str(1)

# %% [markdown]
# <p>And there is no reason why we shouldn't be able to make floats into strings as well:</p>

# %%
# Convert a float to a string

str(1.2)

# %% [markdown]
# <h3 id="bool">Boolean data type</h3>

# %% [markdown]
# <p><i>Boolean</i> is another important type in Python. An object of type <i>Boolean</i> can take on one of two values: <code>True</code> or <code>False</code>:</p>

# %%
# Value true

True

# %% [markdown]
# <p>Notice that the value <code>True</code> has an uppercase "T". The same is true for <code>False</code> (i.e. you must use the uppercase "F").</p>

# %%
# Value false

False

# %% [markdown]
# <p>When you ask Python to display the type of a boolean object it will show <code>bool</code> which stands for <i>boolean</i>:</p>

# %%
# Type of True

type(True)

# %%
# Type of False

type(False)

# %% [markdown]
# <p>We can cast boolean objects to other data types. If we cast a boolean with a value of <code>True</code> to an integer or float we will get a one. If we cast a boolean with a value of <code>False</code> to an integer or float we will get a zero. Similarly, if we cast a 1 to a Boolean, you get a <code>True</code>. And if we cast a 0 to a Boolean we will get a <code>False</code>. Let's give it a try:</p>

# %%
# Convert True to int

int(True)

# %%
# Convert 1 to boolean

bool(1)

# %%
# Convert 0 to boolean

bool(0)

# %%
# Convert True to float

float(True)

# %% [markdown]
# <h3 id="exer_type">Exercise: Types</h3>

# %% [markdown]
# <p>What is the data type of the result of: <code>6 / 2</code>?</p>

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell
type(6/2)

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# type(6/2) # float
# -->

# %% [markdown]
# <p>What is the type of the result of: <code>6 // 2</code>? (Note the double slash <code>//</code>.)</p>

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell
type(6//2)

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# type(6//2) # int, as the double slashes stand for integer division
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# <h2 id="expressions">Expression and Variables</h2>

# %% [markdown]
# <h3 id="exp">Expressions</h3>

# %% [markdown]
# <p>Expressions in Python can include operations among compatible types (e.g., integers and floats). For example, basic arithmetic operations like adding multiple numbers:</p>

# %%
# Addition operation expression

43 + 60 + 16 + 41

# %% [markdown]
# <p>We can perform subtraction operations using the minus operator. In this case the result is a negative number:</p>

# %%
# Subtraction operation expression

50 - 60

# %% [markdown]
# <p>We can do multiplication using an asterisk:</p>

# %%
# Multiplication operation expression

5 * 5

# %% [markdown]
# <p>We can also perform division with the forward slash:

# %%
# Division operation expression

25 / 5

# %%
# Division operation expression

25 / 6

# %% [markdown]
# <p>As seen in the quiz above, we can use the double slash for integer division, where the result is rounded to the nearest integer:

# %%
# Integer division operation expression

25 // 5

# %%
# Integer division operation expression

25 // 6

# %% [markdown]
# <h3 id="exer_exp">Exercise: Expression</h3>

# %% [markdown]
# <p>Let's write an expression that calculates how many hours there are in 160 minutes:

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell
160/60

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# 160/60
# # Or
# 160//60
# -->

# %% [markdown]
# <p>Python follows well accepted mathematical conventions when evaluating mathematical expressions. In the following example, Python adds 30 to the result of the multiplication (i.e., 120).

# %%
# Mathematical expression

30 + 2 * 60

# %% [markdown]
# <p>And just like mathematics, expressions enclosed in parentheses have priority. So the following multiplies 32 by 60.

# %%
# Mathematical expression

(30 + 2) * 60

# %% [markdown]
# <h3 id="var">Variables</h3>

# %% [markdown]
# <p>Just like with most programming languages, we can store values in <i>variables</i>, so we can use them later on. For example:</p>

# %%
# Store value into variable

x = 43 + 60 + 16 + 41

# %% [markdown]
# <p>To see the value of <code>x</code> in a Notebook, we can simply place it on the last line of a cell:</p>

# %%
# Print out the value in variable

x

# %% [markdown]
# <p>We can also perform operations on <code>x</code> and save the result to a new variable:</p>

# %%
# Use another variable to store the result of the operation between variable and value

y = x / 60
y

# %% [markdown]
# <p>If we save a value to an existing variable, the new value will overwrite the previous value:</p>

# %%
# Overwrite variable with new value

x = x / 60
x

# %% [markdown]
# <p>It's a good practice to use meaningful variable names, so you and others can read the code and understand it more easily:</p>

# %%
# Name the variables meaningfully

total_min = 43 + 42 + 57 # Total length of albums in minutes
total_min

# %%
# Name the variables meaningfully

total_hours = total_min / 60 # Total length of albums in hours 
total_hours

# %% [markdown]
# <p>In the cells above we added the length of three albums in minutes and stored it in <code>total_min</code>. We then divided it by 60 to calculate total length <code>total_hours</code> in hours. You can also do it all at once in a single expression, as long as you use parenthesis to add the albums length before you divide, as shown below.</p>

# %%
# Complicate expression

total_hours = (43 + 42 + 57) / 60  # Total hours in a single expression
total_hours

# %% [markdown]
# <p>If you'd rather have total hours as an integer, you can of course replace the floating point division with integer division (i.e., <code>//</code>).</p>

# %% [markdown]
# <h3 id="exer_exp_var">Exercise: Expression and Variables in Python</h3>

# %% [markdown]
# <p>What is the value of <code>x</code> where <code>x = 3 + 2 * 2</code></p>

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# 7
# -->

# %% [markdown]
# <p>What is the value of <code>y</code> where <code>y = (3 + 2) * 2</code>?</p>

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# 10
# -->

# %% [markdown]
# <p>What is the value of <code>z</code> where <code>z = x + y</code>?</p>

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# 17
# -->

# %% [markdown]
# <hr>
# <h2>The last exercise!</h2>
# <p>Congratulations, you have completed your first lesson and hands-on lab in Python. However, there is one more thing you need to do. The Data Science community encourages sharing work. The best way to share and showcase your work is to share it on GitHub. By sharing your notebook on GitHub you are not only building your reputation with fellow data scientists, but you can also show it off when applying for a job. Even though this was your first piece of work, it is never too early to start building good habits. So, please read and follow <a href="https://cognitiveclass.ai/blog/data-scientists-stand-out-by-sharing-your-notebooks/" target="_blank">this article</a> to learn how to share your work.
# <hr>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <h2>Get IBM Watson Studio free of charge!</h2>
#     <p><a href="https://cocl.us/bottemNotebooksPython101Coursera"><img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Ad/BottomAd.png" width="750" align="center"></a></p>
# </div>

# %% [markdown]
# <h3>About the Authors:</h3>
# <p><a href="https://www.linkedin.com/in/joseph-s-50398b136/" target="_blank">Joseph Santarcangelo</a> is a Data Scientist at IBM, and holds a PhD in Electrical Engineering. His research focused on using Machine Learning, Signal Processing, and Computer Vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.</p>

# %% [markdown]
# Other contributors: <a href="www.linkedin.com/in/jiahui-mavis-zhou-a4537814a">Mavis Zhou</a>

# %% [markdown]
# <hr>
# <p>Copyright &copy; 2018 IBM Developer Skills Network. This notebook and its source code are released under the terms of the <a href="https://cognitiveclass.ai/mit-license/">MIT License</a>.</p>
