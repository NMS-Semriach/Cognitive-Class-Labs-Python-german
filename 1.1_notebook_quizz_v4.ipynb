# %% [markdown]
# <h3>Hello World</h3>

# %% [markdown]
# Sagen wir der Welt Hallo mit einer <code>PRINT</code> Anweisung. Z.B. <code>print("Hello World")</code>. Versuche hier einmal eine print-Anweisung in der Zelle unten einzufügen. Vergiss nicht, <kbd>shift</kbd>+<kbd>enter</kbd> zu verwenden, um die Zelle auszuführen:

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# <h3>Sage Hello World in zwei Zeilen</h3>

# %% [markdown]
# Wir wollen Hello und World auf zwei getrennten Zeilen ausgeben. Hinweis: \n in der Mitte der Zeichenkette wirkt wie ein Zeilenumbruch. Z.B. <code>print("line 1\nline 2")</code>. Lass es uns jetzt versuchen. Gib eine Druckanweisung in die untenstehende Zelle ein. Denk daran, <kbd>shift</kbd>+<kbd>enter</kbd> zu verwenden, um die Zelle auszuführen:

# %% [markdown]
# <h3>Kommentare sind der Schlüssel zu einer guten Programmierung.</h3>

# %% [markdown]
# In Python werden Kommentare erstellt, indem eine Hash-Markierung <code>#</code> vor den Text des Kommentars gesetzt wird. Z.B. <code># Dies ist ein Kommentar</code>.

# %% [markdown]
# <hr>
# <small>Copyright &copy; 2018 IBM Cognitive Class. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/).</small>
