# %% [markdown]
# <h3>Vergleichsoperationen</h3>

# %% [markdown]
# Finde den Wert von <code>i</code>, der <code>True</code> erzeugt.

# %%
i=
i>100

# %% [markdown]
# <h3>Verzweigung </h3>

# %% [markdown]
# Finde den Wert von <code>x</code>, der die Anweisung ausgibt: <code>"das ist ein a"</code>

# %%
x=
if(x=='a'):
    print("das ist ein a")
else:
    print("das ist kein a")

# %% [markdown]
# <h3>Logik-Operatoren</h3>

# %% [markdown]
# Finde einen Wert von <code>y</code>, der eine <code>True</code> Anweisung erzeugt

# %%
y=
x=1
x>0 and y<10

# %% [markdown]
# <hr>
# <small>Copyright &copy; 2018 IBM Cognitive Class. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/).</small>
