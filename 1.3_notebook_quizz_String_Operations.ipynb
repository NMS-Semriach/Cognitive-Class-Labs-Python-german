# %% [markdown]
# <h3 align=center>Slicing </h3>

# %% [markdown]
# Verwende Slicing, um die ersten vier Elemente des folgenden Strings zu finden:

# %%
Buchstaben="ABCDEFGHIJK"

# %% [markdown]
# <h3 align=center>Schritte sind gut </h3>

# %% [markdown]
# Verwendet einen Schrittwert von zwei beim folgenden String :

# %%
Good="GsoAo+d"

# %% [markdown]
# <h3 align=center>upper für die GROSSSCHREIBUNG </h3>

# %% [markdown]
# Den folgenden String mit der Methode <code>upper()</code> in Großbuchstaben umwandeln

# %%
"grossgeschrieben"

# %% [markdown]
# <hr>
# <small>Copyright &copy; 2018 IBM Cognitive Class. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/).</small>
