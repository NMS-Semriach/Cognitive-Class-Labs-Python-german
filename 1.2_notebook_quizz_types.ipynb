# %% [markdown]
# <h3 align=center>Hello World</h3>

# %% [markdown]
# Finde den Typ des folgenden Ausdrucks mit dem Befehl <code>type</code>:

# %%
"Hello World"

# %% [markdown]
# <h3 align=center>Typen und Casting </h3>

# %% [markdown]
# Finde den Typ des folgenden Ausdrucks mit dem Befehl <code>type</code>:

# %%
"1.1"

# %% [markdown]
# <h3 align=center>Ist eine Zahl immer eine Zahl
# </h3>

# %% [markdown]
# Der folgende Ausdruck soll in einen <code>int</code>- und dann in einen <code>bool</code>-Wert umgewandelt werden.

# %%
"1"

# %% [markdown]
# <hr>
# <small>Copyright &copy; 2018 IBM Cognitive Class. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/).</small>
